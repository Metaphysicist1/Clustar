# %% [markdown]
# # NASA Near-Earth Object Analysis
#
# This notebook analyzes NEO data for clustering and pattern discovery.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %%
df = pd.read_csv('nasa_neo_browse_dataset.csv')

# %% [markdown]
# ## Data Loading & Initial Inspection
#
# Loading the NASA NEO dataset and examining its basic properties.

# %%
df.shape
# Out:
# (110, 19)

# %%
df.columns
# Out:
# Index(['id', 'neo_reference_id', 'name', 'nasa_jpl_url',
#        'absolute_magnitude_h', 'is_potentially_hazardous_asteroid',
#        'close_approach_data', 'is_sentry_object', 'links.self',
#        'estimated_diameter.kilometers.estimated_diameter_min',
#        'estimated_diameter.kilometers.estimated_diameter_max',
#        'estimated_diameter.meters.estimated_diameter_min',
#        'estimated_diameter.meters.estimated_diameter_max',
#        'estimated_diameter.miles.estimated_diameter_min',
#        'estimated_diameter.miles.estimated_diameter_max',
#        'estimated_diameter.feet.estimated_diameter_min',
#        'estimated_diameter.feet.estimated_diameter_max', 'sentry_data',
#        'observation_date'],
#       dtype='object')

# %%
df.head()
# Out:
#         id  neo_reference_id               name  \
# 0  2436030           2436030  436030 (2009 JO2)
# 1  3137735           3137735        (2002 TX59)
# 2  3153509           3153509          (2003 HM)
# 3  3654379           3654379         (2013 XV8)
# 4  3830886           3830886         (2018 SN2)
#
#                                         nasa_jpl_url  absolute_magnitude_h  \
# 0  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 19.44
# 1  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 23.90
# 2  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 22.04
# 3  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 21.89
# 4  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 24.40
#
#    is_potentially_hazardous_asteroid  \
# 0                              False
# 1                              False
# 2                               True
# 3                              False
# 4                              False
#
#                                  close_approach_data  is_sentry_object  \
# 0  [{'close_approach_date': '2025-04-20', 'close_...             False
# 1  [{'close_approach_date': '2025-04-20', 'close_...             False
# 2  [{'close_approach_date': '2025-04-20', 'close_...             False
# 3  [{'close_approach_date': '2025-04-20', 'close_...             False
# 4  [{'close_approach_date': '2025-04-20', 'close_...             False
#
#                                           links.self  \
# 0  http://api.nasa.gov/neo/rest/v1/neo/2436030?ap...
# 1  http://api.nasa.gov/neo/rest/v1/neo/3137735?ap...
# 2  http://api.nasa.gov/neo/rest/v1/neo/3153509?ap...
# 3  http://api.nasa.gov/neo/rest/v1/neo/3654379?ap...
# 4  http://api.nasa.gov/neo/rest/v1/neo/3830886?ap...
#
#    estimated_diameter.kilometers.estimated_diameter_min  \
# 0                                           0.343997
# 1                                           0.044112
# 2                                           0.103886
# 3                                           0.111315
# 4                                           0.035039
#
#    estimated_diameter.kilometers.estimated_diameter_max  \
# 0                                           0.769201
# 1                                           0.098637
# 2                                           0.232295
# 3                                           0.248909
# 4                                           0.078350
#
#    estimated_diameter.meters.estimated_diameter_min  \
# 0                                        343.997255
# 1                                         44.111820
# 2                                        103.885510
# 3                                        111.315330
# 4                                         35.039264
#
#    estimated_diameter.meters.estimated_diameter_max  \
# 0                                        769.201245
# 1                                         98.637028
# 2                                        232.295062
# 3                                        248.908644
# 4                                         78.350176
#
#    estimated_diameter.miles.estimated_diameter_min  \
# 0                                         0.213750
# 1                                         0.027410
# 2                                         0.064551
# 3                                         0.069168
# 4                                         0.021772
#
#    estimated_diameter.miles.estimated_diameter_max  \
# 0                                         0.477959
# 1                                         0.061290
# 2                                         0.144341
# 3                                         0.154665
# 4                                         0.048685
#
#    estimated_diameter.feet.estimated_diameter_min  \
# 0                                     1128.599953
# 1                                      144.723824
# 2                                      340.831737
# 3                                      365.207786
# 4                                      114.958219
#
#    estimated_diameter.feet.estimated_diameter_max sentry_data observation_date
# 0                                     2523.626214         NaN       2025-04-20
# 1                                      323.612307         NaN       2025-04-20
# 2                                      762.122933         NaN       2025-04-20
# 3                                      816.629435         NaN       2025-04-20
# 4                                      257.054393         NaN       2025-04-20

# %%
df.isnull().sum()
# Out:
# id                                                        0
# neo_reference_id                                          0
# name                                                      0
# nasa_jpl_url                                              0
# absolute_magnitude_h                                      0
# is_potentially_hazardous_asteroid                         0
# close_approach_data                                       0
# is_sentry_object                                          0
# links.self                                                0
# estimated_diameter.kilometers.estimated_diameter_min      0
# estimated_diameter.kilometers.estimated_diameter_max      0
# estimated_diameter.meters.estimated_diameter_min          0
# estimated_diameter.meters.estimated_diameter_max          0
# estimated_diameter.miles.estimated_diameter_min           0
# estimated_diameter.miles.estimated_diameter_max           0
# estimated_diameter.feet.estimated_diameter_min            0
# estimated_diameter.feet.estimated_diameter_max            0
# sentry_data                                             105
# observation_date                                          0
# dtype: int64

# %% [markdown]
# ## Missing Value Analysis
#
# Checking for null values to inform cleaning decisions.

# %% [markdown]
# ##### Because sentry_data have a lot of null values I am gonna remove column

# %%
df.drop(['sentry_data','id','neo_reference_id'],axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# name                                                    0
# nasa_jpl_url                                            0
# absolute_magnitude_h                                    0
# is_potentially_hazardous_asteroid                       0
# close_approach_data                                     0
# is_sentry_object                                        0
# links.self                                              0
# estimated_diameter.kilometers.estimated_diameter_min    0
# estimated_diameter.kilometers.estimated_diameter_max    0
# estimated_diameter.meters.estimated_diameter_min        0
# estimated_diameter.meters.estimated_diameter_max        0
# estimated_diameter.miles.estimated_diameter_min         0
# estimated_diameter.miles.estimated_diameter_max         0
# estimated_diameter.feet.estimated_diameter_min          0
# estimated_diameter.feet.estimated_diameter_max          0
# observation_date                                        0
# dtype: int64

# %% [markdown]
# ##### Choosing columns for further processing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 16 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   name                                                  110 non-null    object
#  1   nasa_jpl_url                                          110 non-null    object
#  2   absolute_magnitude_h                                  110 non-null    float64
#  3   is_potentially_hazardous_asteroid                     110 non-null    bool
#  4   close_approach_data                                   110 non-null    object
#  5   is_sentry_object                                      110 non-null    bool
#  6   links.self                                            110 non-null    object
#  7   estimated_diameter.kilometers.estimated_diameter_min  110 non-null    float64
#  8   estimated_diameter.kilometers.estimated_diameter_max  110 non-null    float64
#  9   estimated_diameter.meters.estimated_diameter_min      110 non-null    float64
#  10  estimated_diameter.meters.estimated_diameter_max      110 non-null    float64
#  11  estimated_diameter.miles.estimated_diameter_min       110 non-null    float64
#  12  estimated_diameter.miles.estimated_diameter_max       110 non-null    float64
#  13  estimated_diameter.feet.estimated_diameter_min        110 non-null    float64
#  14  estimated_diameter.feet.estimated_diameter_max        110 non-null    float64
#  15  observation_date                                      110 non-null    object
# dtypes: bool(2), float64(9), object(5)
# memory usage: 12.4+ KB

# %%
df['is_potentially_hazardous_asteroid'] = df['is_potentially_hazardous_asteroid'].astype(np.int64)
df['is_sentry_object'] = df['is_sentry_object'].astype(np.int64)

# %%
df.head()
# Out:
#                 name                                       nasa_jpl_url  \
# 0  436030 (2009 JO2)  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...
# 1        (2002 TX59)  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...
# 2          (2003 HM)  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...
# 3         (2013 XV8)  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...
# 4         (2018 SN2)  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...
#
#    absolute_magnitude_h  is_potentially_hazardous_asteroid  \
# 0                 19.44                                  0
# 1                 23.90                                  0
# 2                 22.04                                  1
# 3                 21.89                                  0
# 4                 24.40                                  0
#
#                                  close_approach_data  is_sentry_object  \
# 0  [{'close_approach_date': '2025-04-20', 'close_...                 0
# 1  [{'close_approach_date': '2025-04-20', 'close_...                 0
# 2  [{'close_approach_date': '2025-04-20', 'close_...                 0
# 3  [{'close_approach_date': '2025-04-20', 'close_...                 0
# 4  [{'close_approach_date': '2025-04-20', 'close_...                 0
#
#                                           links.self  \
# 0  http://api.nasa.gov/neo/rest/v1/neo/2436030?ap...
# 1  http://api.nasa.gov/neo/rest/v1/neo/3137735?ap...
# 2  http://api.nasa.gov/neo/rest/v1/neo/3153509?ap...
# 3  http://api.nasa.gov/neo/rest/v1/neo/3654379?ap...
# 4  http://api.nasa.gov/neo/rest/v1/neo/3830886?ap...
#
#    estimated_diameter.kilometers.estimated_diameter_min  \
# 0                                           0.343997
# 1                                           0.044112
# 2                                           0.103886
# 3                                           0.111315
# 4                                           0.035039
#
#    estimated_diameter.kilometers.estimated_diameter_max  \
# 0                                           0.769201
# 1                                           0.098637
# 2                                           0.232295
# 3                                           0.248909
# 4                                           0.078350
#
#    estimated_diameter.meters.estimated_diameter_min  \
# 0                                        343.997255
# 1                                         44.111820
# 2                                        103.885510
# 3                                        111.315330
# 4                                         35.039264
#
#    estimated_diameter.meters.estimated_diameter_max  \
# 0                                        769.201245
# 1                                         98.637028
# 2                                        232.295062
# 3                                        248.908644
# 4                                         78.350176
#
#    estimated_diameter.miles.estimated_diameter_min  \
# 0                                         0.213750
# 1                                         0.027410
# 2                                         0.064551
# 3                                         0.069168
# 4                                         0.021772
#
#    estimated_diameter.miles.estimated_diameter_max  \
# 0                                         0.477959
# 1                                         0.061290
# 2                                         0.144341
# 3                                         0.154665
# 4                                         0.048685
#
#    estimated_diameter.feet.estimated_diameter_min  \
# 0                                     1128.599953
# 1                                      144.723824
# 2                                      340.831737
# 3                                      365.207786
# 4                                      114.958219
#
#    estimated_diameter.feet.estimated_diameter_max observation_date
# 0                                     2523.626214       2025-04-20
# 1                                      323.612307       2025-04-20
# 2                                      762.122933       2025-04-20
# 3                                      816.629435       2025-04-20
# 4                                      257.054393       2025-04-20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 16 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   name                                                  110 non-null    object
#  1   nasa_jpl_url                                          110 non-null    object
#  2   absolute_magnitude_h                                  110 non-null    float64
#  3   is_potentially_hazardous_asteroid                     110 non-null    int64
#  4   close_approach_data                                   110 non-null    object
#  5   is_sentry_object                                      110 non-null    int64
#  6   links.self                                            110 non-null    object
#  7   estimated_diameter.kilometers.estimated_diameter_min  110 non-null    float64
#  8   estimated_diameter.kilometers.estimated_diameter_max  110 non-null    float64
#  9   estimated_diameter.meters.estimated_diameter_min      110 non-null    float64
#  10  estimated_diameter.meters.estimated_diameter_max      110 non-null    float64
#  11  estimated_diameter.miles.estimated_diameter_min       110 non-null    float64
#  12  estimated_diameter.miles.estimated_diameter_max       110 non-null    float64
#  13  estimated_diameter.feet.estimated_diameter_min        110 non-null    float64
#  14  estimated_diameter.feet.estimated_diameter_max        110 non-null    float64
#  15  observation_date                                      110 non-null    object
# dtypes: float64(9), int64(2), object(5)
# memory usage: 13.9+ KB

# %%
numerical_features = df.select_dtypes(include=[np.number]).columns.tolist()

# %%
numerical_features
# Out:
# ['absolute_magnitude_h',
#  'is_potentially_hazardous_asteroid',
#  'is_sentry_object',
#  'estimated_diameter.kilometers.estimated_diameter_min',
#  'estimated_diameter.kilometers.estimated_diameter_max',
#  'estimated_diameter.meters.estimated_diameter_min',
#  'estimated_diameter.meters.estimated_diameter_max',
#  'estimated_diameter.miles.estimated_diameter_min',
#  'estimated_diameter.miles.estimated_diameter_max',
#  'estimated_diameter.feet.estimated_diameter_min',
#  'estimated_diameter.feet.estimated_diameter_max']

# %%
df = df[numerical_features]

# %%
df.head()
# Out:
#    absolute_magnitude_h  is_potentially_hazardous_asteroid  is_sentry_object  \
# 0                 19.44                                  0                 0
# 1                 23.90                                  0                 0
# 2                 22.04                                  1                 0
# 3                 21.89                                  0                 0
# 4                 24.40                                  0                 0
#
#    estimated_diameter.kilometers.estimated_diameter_min  \
# 0                                           0.343997
# 1                                           0.044112
# 2                                           0.103886
# 3                                           0.111315
# 4                                           0.035039
#
#    estimated_diameter.kilometers.estimated_diameter_max  \
# 0                                           0.769201
# 1                                           0.098637
# 2                                           0.232295
# 3                                           0.248909
# 4                                           0.078350
#
#    estimated_diameter.meters.estimated_diameter_min  \
# 0                                        343.997255
# 1                                         44.111820
# 2                                        103.885510
# 3                                        111.315330
# 4                                         35.039264
#
#    estimated_diameter.meters.estimated_diameter_max  \
# 0                                        769.201245
# 1                                         98.637028
# 2                                        232.295062
# 3                                        248.908644
# 4                                         78.350176
#
#    estimated_diameter.miles.estimated_diameter_min  \
# 0                                         0.213750
# 1                                         0.027410
# 2                                         0.064551
# 3                                         0.069168
# 4                                         0.021772
#
#    estimated_diameter.miles.estimated_diameter_max  \
# 0                                         0.477959
# 1                                         0.061290
# 2                                         0.144341
# 3                                         0.154665
# 4                                         0.048685
#
#    estimated_diameter.feet.estimated_diameter_min  \
# 0                                     1128.599953
# 1                                      144.723824
# 2                                      340.831737
# 3                                      365.207786
# 4                                      114.958219
#
#    estimated_diameter.feet.estimated_diameter_max
# 0                                     2523.626214
# 1                                      323.612307
# 2                                      762.122933
# 3                                      816.629435
# 4                                      257.054393

# %% [markdown]
# ## Feature Selection Results
#
# The selected numerical features include:
# - Absolute magnitude (brightness)
# - Binary indicators (hazardous, sentry)
# - Estimated diameter measurements in different units
#
# These features will be used for clustering to identify groups of similar NEOs.

# %% [markdown]
# ## Next Steps
#
# 1. Remove redundant features (different unit measurements of the same values)
# 2. Apply feature scaling to normalize the data before clustering
# 3. Perform dimensionality reduction with PCA
# 4. Apply KMeans clustering and evaluate with silhouette score
# 5. Visualize and interpret the results

# %%
# Out:
# 2025-04-01 2025-04-08
# 2025-04-08 2025-04-15
# 2025-04-15 2025-04-22
# 2025-04-22 2025-04-29
